# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
years = np.arange(1960, 2021, 1)

# %%
years
# Out:
# array([1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970,
#        1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981,
#        1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992,
#        1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003,
#        2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014,
#        2015, 2016, 2017, 2018, 2019, 2020])

# %%
len(years)
# Out:
# 61

# %%
gdp = [180, 191, 203, 216, 229, 243, 257, 271, 286, 306, 322, 331, 416, 507, 467, 710, 807, 498, 564, 590, 603, 699, 774, 733, 788, 876, 930, 1010, 1040, 1090, 917]

# %%
len(gdp)
# Out:
# 31

# %%
no_data_gdp = np.arange(900, 4570, 170)

# %%
no_data_gdp = [x / 1000 for x in no_data_gdp]

# %%
len(no_data_gdp)
# Out:
# 22

# %%
no_data_years = np.arange(1991, 2013, 1)

# %%
gdp = [y for x in [gdp, no_data_gdp] for y in x]

# %%
len(gdp)
# Out:
# 53

# %%
gdp = [y for x in [gdp, [4570, 5020, 5330, 5530, 5610, 5850, 6480, 6970]] for y in x]

# %%
gdp = [x / 1000 for x in gdp]

# %%
f = plt.figure()
f.set_figwidth(15)
f.set_figheight(10)
plt.rcParams.update({'font.size': 22})
plt.plot(years, gdp_per_capita)
plt.plot(no_data_years, no_data_gdp, linestyle = '--', linewidth = 2, color = 'orange')
plt.xlabel('Year')
plt.ylabel('GDP, billion USD')
plt.show()

# %%
years = np.arange(1960, 2021, 1)

# %%
len(years)
# Out:
# 61

# %%
gdp_per_capita = [65, 68, 70, 73, 76, 79, 81, 84, 86, 90, 93, 95, 119, 144, 128, 183, 188, 103, 105, 100, 96, 107, 117, 110, 119, 131, 138, 147, 148, 153, 126]

# %%
len(gdp_per_capita)
# Out:
# 31

# %%
no_data_gdp_per_capita = np.arange(126, 350, 10.5)
len(no_data_gdp_per_capita)
# Out:
# 22

# %%
gdp_per_capita = [y for x in [gdp_per_capita, no_data_gdp_per_capita] for y in x]
len(gdp_per_capita)
# Out:
# 53

# %%
gdp_per_capita = [y for x in [gdp_per_capita, [350, 374, 386, 389, 384, 389, 419, 438]] for y in x]
len(gdp_per_capita)
# Out:
# 61

# %%
f = plt.figure()
f.set_figwidth(15)
f.set_figheight(10)
plt.rcParams.update({'font.size': 22})
plt.plot(years, gdp_per_capita)
plt.plot(no_data_years, no_data_gdp_per_capita, linestyle = '--', linewidth = 2, color = 'orange')
plt.xlabel('Year')
plt.ylabel('GDP per capita, USD')
plt.show()

# %%
years = np.arange(1961, 2021, 1)
len(years)
# Out:
# 60

# %%
gdp_annual_growth = [-3.3, 7.1, 2.8, -6.1, -5.9, 9.1, 5.9, 2, -1.7, 4.6, 2.6, 10.1, -2, 18.3, 30.1, -1, 23.3, 3.7, -2.7, -3.9, 5.7, 4.1, -8.8, 3.6, 8.2, 3.4, 5.1, -0.6, -0.2, -1.5]
len(gdp_annual_growth)
# Out:
# 30

# %%
no_data_years = np.arange(1991, 2014, 1)

# %%
no_data_gdp_annual_growth = np.zeros(23)
len(no_data_gdp_annual_growth)
# Out:
# 23

# %%
gdp_annual_growth = [y for x in [gdp_annual_growth, no_data_gdp_annual_growth] for y in x]
len(gdp_annual_growth)
# Out:
# 53

# %%
gdp_annual_growth = [y for x in [gdp_annual_growth, [7.5, 14.9, 8.4, 2.6, 7.7, 8.1, 2.4]] for y in x]
len(gdp_annual_growth)
# Out:
# 60

# %%
f = plt.figure()
f.set_figwidth(15)
f.set_figheight(10)
plt.rcParams.update({'font.size': 22})
plt.plot(years, gdp_annual_growth)
plt.plot(no_data_years, no_data_gdp_annual_growth, linestyle = '--', linewidth = 2, color = 'orange')
plt.hlines(y=0, xmin=1960, xmax=2020, colors='black', linestyles='--', lw=2)
plt.xlabel('Year')
plt.ylabel('GDP annual growth, %')
plt.show()
